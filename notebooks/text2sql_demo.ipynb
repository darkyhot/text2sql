# %% [markdown]
# # Text2SQL — управление из одной ячейки
#
# Запусти ячейку ниже и работай как в консоли: пиши запрос → агент покажет **план** → ответь `ok` (выполнить) или текстом (правка плана); при неоднозначности введи номер варианта.
#
# **Поле ввода растёт вниз по мере текста** — удобно для длинных промтов. Отправка: кнопка **«Отправить»** или **Ctrl+Enter**; Enter — новая строка.
#
# Команды: `/help`, `/refresh_metadata`, `/reset`, `/clear`, `/exit`.
#
# Перед запуском: `docker start db-agent-test-pg` и заполненный `.env`.
#
# Результат каждого запроса сохраняется в `workspace/last_query.csv`.

# %%
import sys, pathlib
sys.path[:0] = [str(pathlib.Path.cwd()), str(pathlib.Path.cwd().parent / 'src')]

from growing_input import install
install()                      # поле ввода растёт вниз по тексту (кнопка / Ctrl+Enter)

from text2sql.cli import CLI

CLI().run()
